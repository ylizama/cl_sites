# %%
import os
import csv
import datetime
import string

# %%
file = open('data/borrador_conjunto.txt', 'r') 
text = file.read() 
file.close()

# %%
stop_words_spanish = ['un', 'una', 'unas', 'unos', 'uno', 'sobre', 'todo', 'también', 'tras', 'otro', 
                      'algún', 'alguno', 'alguna', 'algunos', 'algunas', 'ser', 'es', 'soy', 'eres',
                      'somos', 'sois', 'estoy', 'esta', 'estamos', 'estais', 'estan', 'como', 'en', 
                      'para', 'atras', 'porque', 'por qué',  'estaba', 'ante', 'antes', 'siendo', 'ambos',
                      'pero', 'por', 'poder', 'puede', 'puedo', 'podemos', 'podeis', 'pueden', 'fui', 'fue',
                      'fuimos', 'fueron', 'hacer', 'hago', 'hace', 'hacemos', 'haceis', 'hacen', 'cada', 'fin',
                      'incluso', 'primero', 'desde', 'conseguir', 'consigo', 'consigue', 'consigues', 'conseguimos', 
                      'consiguen', 'ir', 'voy', 'va', 'vamos', 'vais', 'van', 'vaya', 'gueno', 'ha', 'el', 'la', 'lo',
                      'las', 'los', 'su', 'aqui', 'mio', 'tuyo', 'ellos', 'ellas', 'nos', 'nosotros', 'vosotros', 
                      'vosotras', 'si', 'dentro', 'solo', 'solamente', 'saber', 'sabes', 'sabe', 'sabemos', 'sabeis',
                      'saben', 'ultimo', 'largo', 'bastante', 'haces', 'muchos', 'aquellos', 'aquellas', 'sus',
                      'entonces', 'tiempo', 'verdad', 'verdadero', 'verdadera', 'cierto', 'ciertos', 'cierta', 'ciertas',
                      'intentar', 'intento', 'intenta', 'intentas', 'intentamos', 'intentais', 'intentan', 'dos', 'bajo',
                      'arriba', 'encima', 'usar', 'uso', 'usas', 'usa', 'usamos', 'usais', 'usan', 'emplear', 'empleo',
                      'empleas', 'emplean', 'ampleamos', 'empleais', 'valor', 'muy', 'era', 'eras', 'eramos', 'eran',
                      'modo', 'bien', 'cual', 'cuando', 'donde', 'mientras', 'quien', 'con', 'entre', 'sin', 'trabajo',
                      'trabajar', 'trabajas', 'trabaja', 'trabajamos', 'trabajais', 'trabajan', 'podria', 'podrias',
                      'podriamos', 'podrian', 'podriais', 'yo', 'aquel', 'a', 'en', 'de', 'para', 'por', 'según', 'sin',
                      'sobre', 'tras', 'bajo', 'contra', 'hacia', 'hasta', 'rt', 'que', 'se', 'no', 'del', 'al', 'http',
                      'https', 'y', 'más', 'todos', 'año', 'será', 'este', 'vía', 'les', 'ni', 'dice', 'le', 'está',
                      'qué', 'hay', 'htt', 'quiere', 'nuestra', 'sí', 'of', 'in', 'años', 'firma' , 'firman', 'nuevo', 
                      'hoy', 'ayer', 'inicio', 'ya', 'día','son', 'final', 'and', 'with', 'you', 'mundo', 'gran', 'sol',
                      'recibe', 'millones',  'gracias', 'hermana','me', 'eso',  'we', 'after',  'dijo','lleve', 
                      'nuevamente', 'ahora', 'ese',  'han', 'sino', 'tal', 'mismos', 'estos', 'así', 'ver', 'esto',
                      'esta', 'sido', 'manera', 'sigo', 'da', 'esa', 'aunque', 'están', 'mil', 'además', 'había', 'él',
                      'después', 'pues', 'vez', 'quienes', 'página', 'conjunto 15122015', '63 borrador', 'víctimas 18',
                      'víctimas 51114']

abc = string.ascii_lowercase 
punct_signs = string.punctuation

# %%
from nltk import ngrams
import operator
from itertools import islice
import string 
from tabulate import tabulate

def stopWordsInGrams(grams):    
    count = 0
    for w in grams:
        if w in stop_words_spanish:
            count = count + 1                
    return count/len(grams)  

def isNumber(s):
    try: 
        int(s)
        float(s)
        return True
    except ValueError:
        return False

def getNGram(text, n, stop_words, m):
    text = text.lower()
    ngramas = ngrams(text.split(), n)
    h_dict = {}   
    for grams in ngramas:
        if stopWordsInGrams(grams) > 0.34:
            continue
        words = ' '.join(grams)        
        words = words.lower() 
        words = ''.join(e for e in words if e.isalnum() or e == ' ')    
        words = words.strip()  
        if  words in stop_words or words in punct_signs or words == '' or words in abc or isNumber(words) or len(words.split(' ')) != n:
             continue
        if words in h_dict:
            h_dict[words] = h_dict[words] + 1
        else: 
            h_dict[words] = 1 
    sorted_dict = sorted(h_dict.items(), key=operator.itemgetter(1), reverse=True)
    if m is -1:
        return list(sorted_dict)
    else:
        return list(islice(sorted_dict, m))

# %% [markdown]
# ## Top 20 Unigramas más frecuentes

# %%
final = getNGram(text, 1, stop_words_spanish, 20)
print(tabulate(final, ['Ngram', 'Number']))
print('---------------------------------')
print()
# Out:
# Ngram              Number
# ---------------  --------
# conflicto             178
# víctimas              168
# derechos              162
# paz                   134
# justicia              120
# comisión              108
# reparación            106
# reconocimiento        100
# repetición             98
# humanos                93
# medidas                92
# acuerdo                89
# responsabilidad        84
# especial               82
# personas               79
# sala                   72
# conjunto               68
# nacional               67
# caso                   67
# borrador               63
# ---------------------------------

# %% [markdown]
# ## Top 20 Bigramas más frecuentes

# %%
final2 = getNGram(text, 2, stop_words_spanish, 20)
print(tabulate(final2, ['Ngram', 'Number']))
print('---------------------------------')
print()
# Out:
# Ngram                        Number
# -------------------------  --------
# derechos humanos                 92
# borrador conjunto                63
# jurisdicción especial            44
# gobierno nacional                38
# derecho internacional            33
# conflicto armado                 32
# sistema integral                 32
# acuerdo final                    28
# verdad justicia                  21
# reparación colectiva             21
# personas dadas                   20
# justicia reparación              20
# internacional humanitario        19
# amnistía o                       15
# graves violaciones               14
# directa o                        14
# o indulto                        12
# reparación integral              12
# enfoque territorial              12
# acuerdo general                  12
# ---------------------------------

# %% [markdown]
# ## Bigramas que contienen la palabra 'Conflicto'

# %%
final3 = getNGram(text, 2, stop_words_spanish, -1)
final4 = []
for i in final3:
    if 'conflicto' in i[0]:
        final4.append(i)
    
print(tabulate(final4, ['Ngram', 'Number']))
print('---------------------------------')
# Out:
# Ngram                    Number
# ---------------------  --------
# conflicto armado             32
# conflicto o                   4
# conflicto puedan              2
# conflicto incluyendo          2
# conflicto teniendo            2
# conflicto requiere            2
# conflicto constituye          2
# conflicto afectó              2
# conflicto deben               1
# conflicto promover            1
# conflicto mediante            1
# conflicto responden           1
# conflicto debería             1
# conflicto 5136                1
# conflicto asegurar            1
# conflicto tales               1
# conflicto enviará             1
# conflicto reconozcan          1
# conflicto permitirá           1
# conflicto restablecer         1
# conflicto e                   1
# conflicto 5134                1
# conflicto 51113               1
# conflicto podrán              1
# conflicto promoción           1
# conflictos deberá             1
# conflicto debe                1
# ...

# %% [markdown]
# ## Bigramas que contienen la palabra 'Víctimas'

# %%
final3 = getNGram(text, 2, stop_words_spanish, -1)
final4 = []
for i in final3:
    if 'víctima' in i[0]:
        final4.append(i)
    
print(tabulate(final4, ['Ngram', 'Number']))
print('---------------------------------')
# Out:
# Ngram                      Number
# -----------------------  --------
# 5 víctimas                      4
# víctimas incluyendo             3
# víctimas existentes             2
# víctimas directas               2
# víctimas mujeres                2
# víctimas testigos               1
# víctimas 514                    1
# otras víctimas                  1
# víctimas gozan                  1
# víctimas participaron           1
# víctimas debería                1
# víctimas tanto                  1
# víctimas marcar                 1
# víctimas iniciamos              1
# víctimas adecuarla              1
# víctimas terminar               1
# agenda víctimas                 1
# víctimas viajaron               1
# sea víctima                     1
# 3000 víctimas                   1
# víctimas invitadas              1
# víctimas buscará                1
# víctimas residentes             1
# víctimas o                      1
# punto víctimas                  1
# ...

# %% [markdown]
# ## Top 20 Unigramas en la misma oración que 'conflicto'

# %%
import re
sentences = text.split('.')
regexp = re.compile(r'[ .,;\'\"]conflicto[ .,;\'\"]')
data_paz = ''
for s in sentences: 
    if regexp.search(s.lower()): 
        data_paz = data_paz + '\n' + s

stop_words = stop_words_spanish[:]
stop_words.append('conflicto')
final5 = getNGram(data_paz, 1,stop_words , 20)
print(tabulate(final5, ['Ngram', 'Number']))
# Out:
# Ngram         Number
# ----------  --------
# víctimas          60
# reparación        42
# derechos          40
# repetición        32
# personas          31
# comisión          26
# marco             26
# acuerdo           25
# gobierno          25
# armado            24
# nacional          23
# contribuir        21
# justicia          19
# integral          19
# medidas           19
# paz               18
# humanos           18
# directa           18
# especial          17
# desarrollo        17

# %% [markdown]
# ## Top 20 Bigramas en la misma oración que 'conflicto'

# %%
sentences = text.split('.')
regexp = re.compile(r'[ .,;\'\"]conflicto[ .,;\'\"]')
data_paz = ''
for s in sentences: 
    if regexp.search(s.lower()): 
        data_paz = data_paz + '\n' + s

stop_words = stop_words_spanish[:]
stop_words.append('conflicto')
final6 = getNGram(data_paz, 2,stop_words , 20)
print(tabulate(final6, ['Ngram', 'Number']))
# Out:
# Ngram                        Number
# -------------------------  --------
# conflicto armado                 24
# gobierno nacional                18
# derechos humanos                 18
# directa o                        14
# personas dadas                   14
# o indirecta                      11
# sistema integral                 11
# reparación colectiva             10
# jurisdicción especial             9
# enfoque territorial               7
# verdad justicia                   6
# graves violaciones                6
# justicia reparación               6
# internacional humanitario         6
# e infracciones                    6
# derecho internacional             6
# hemos acordado                    6
# acuerdo final                     5
# múltiples causas                  5
# paz estable                       5

# %% [markdown]
# ## Top 20 Unigramas en la misma oración que 'víctimas'

# %%
sentences = text.split('.')
regexp = re.compile(r'[ .,;\'\"]víctimas[ .,;\'\"]')
data_paz = ''
for s in sentences: 
    if regexp.search(s.lower()): 
        data_paz = data_paz + '\n' + s

stop_words = stop_words_spanish[:]
stop_words.append('víctimas')
final6 = getNGram(data_paz, 1,stop_words , 20)
print(tabulate(final6, ['Ngram', 'Number']))
# Out:
# Ngram             Number
# --------------  --------
# conflicto             61
# derechos              58
# reparación            50
# repetición            33
# justicia              30
# reconocimiento        27
# nacional              26
# integral              25
# participación         24
# organizaciones        24
# humanos               23
# acuerdo               22
# gobierno              21
# paz                   20
# comisión              20
# medidas               19
# satisfacción          18
# marco                 17
# parte                 17
# incluyendo            15

# %% [markdown]
# ## Top 20 Bigramas en la misma oración que 'víctimas'

# %%
sentences = text.split('.')
regexp = re.compile(r'[ .,;\'\"]víctimas[ .,;\'\"]')
data_paz = ''
for s in sentences: 
    if regexp.search(s.lower()): 
        data_paz = data_paz + '\n' + s

stop_words = stop_words_spanish[:]
stop_words.append('víctimas')
final6 = getNGram(data_paz, 2,stop_words , 20)
print(tabulate(final6, ['Ngram', 'Number']))
# Out:
# Ngram                        Number
# -------------------------  --------
# derechos humanos                 23
# gobierno nacional                17
# sistema integral                 12
# reparación integral              10
# justicia reparación               9
# verdad justicia                   9
# graves violaciones                6
# conflicto armado                  6
# enfoque territorial               5
# jurisdicción especial             5
# reparación colectiva              5
# hemos acordado                    5
# acuerdo final                     4
# personas desaparecidas            4
# internacional humanitario         4
# derecho internacional             4
# personas dadas                    3
# conjunto 15                       3
# o infracciones                    3
# múltiples causas                  3

# %%
secciones = {'5.1.1 Verdad': 'data/borrador_conjunto/verdad.txt',
             '5.1.2 Justicia': 'data/borrador_conjunto/justicia.txt',
             '5.1.3 Reparación': 'data/borrador_conjunto/reparacion.txt', 
             '5.1.4 No repetición': 'data/borrador_conjunto/no_repeticion.txt'}

# %% [markdown]
# ## Unigramas y Bigramas más frecuentes por secciones del Borrador Conjunto 15-12-2015

# %% [markdown]
# ###### ubpd - Unidad de Búsqueda de Personas dadas por Desaparecidas
# ###### sivjrnr - Sistema integral de Verdad, Justicia, Reparación y no Repetición

# %%
for key in sorted(secciones.keys()):
    print(key)
    print()
    print('--------------------------------------------------------------------')
    readfile = open(secciones[key], 'r')
    text = readfile.read()
    final = getNGram(text, 1, stop_words_spanish, 20)
    final2 = getNGram(text, 2, stop_words_spanish, 20)
    final3 = []
    for i in range(0,20):
        final3.append(final[i] + final2[i])
    print(tabulate(final3, ['Unigrams', 'Number', 'Bigrams', 'Number'],  tablefmt="presto", numalign="center"))
    print('--------------------------------------------------------------------')
    print()
# Out:
# 5.1.1 Verdad
#
# --------------------------------------------------------------------
#  Unigrams       |  Number  | Bigrams                 |  Number
# ----------------+----------+-------------------------+----------
#  comisión       |    89    | personas dadas          |    14
#  conflicto      |    53    | derechos humanos        |    13
#  víctimas       |    33    | gobierno nacional       |    9
#  personas       |    28    | conflicto armado        |    8
#  ubpd           |    24    | comisión deberá         |    7
#  información    |    23    | personas desaparecidas  |    6
#  derechos       |    23    | medidas necesarias      |    6
#  repetición     |    23    | entrega digna           |    6
#  nacional       |    20    | comisión tendrá         |    5
#  funciones      |    20    | procesos judiciales     |    5
#  desaparecidas  |    20    | enfoque territorial     |    4
#  contribuir     |    19    | acuerdo final           |    4
# ...

# %% [markdown]
# ## Bigramas y Trigramas más frecuentes que contienen la palabra 'víctimas' por secciones del Borrador Conjunto 15-12-2015

# %% [markdown]
# #### Añadí los trigramas para que tener un contexto más amplio para el análisis, pero las frecuencias son mínimas, generalmente de 1.

# %%
for key in sorted(secciones.keys()):
    print(key)
    print()
    print('--------------------------------------------------------------------')
    readfile = open(secciones[key], 'r')
    text = readfile.read()
    final1 = getNGram(text, 2, stop_words_spanish, -1)
    final2 = []
    for i in final1:
        if 'víctima' in i[0]:
              final2.append(i)
    print(tabulate(final2, ['Bigrams', 'Number'],  tablefmt="presto", numalign="center"))
    print('--------------------------------------------------------------------')
    print()        
    final12 = getNGram(text, 3, stop_words_spanish, -1)
    final22 = []
    for i in final12:
        if 'víctima' in i[0]:
            final22.append(i)
    print(tabulate(final22, ['Trigrams', 'Number'],  tablefmt="presto", numalign="center"))
    print('---------------------------------------------------------------------')
    print()
# Out:
# 5.1.1 Verdad
#
# --------------------------------------------------------------------
#  Bigrams                 |  Number
# -------------------------+----------
#  víctimas terminar       |    1
#  víctimas tanto          |    1
#  víctimas organizaciones |    1
# --------------------------------------------------------------------
#
#  Trigrams                           |  Number
# ------------------------------------+----------
#  organizaciones de víctimas         |    9
#  víctimas entre otros               |    3
#  víctimas del conflicto             |    2
#  las víctimas terminar              |    1
#  de víctimas organizaciones         |    1
#  víctimas terminar el               |    1
#  víctimas se vean                   |    1
#  víctimas los esfuerzos             |    1
#  las víctimas tanto                 |    1
#  víctimas 51114 funciones           |    1
#  víctimas organizaciones defensoras |    1
#  víctimas como ciudadanos           |    1
# ...

# %% [markdown]
# ## Unigramas y Bigramas más frecuentes en la misma oración que 'víctimas' por secciones del Borrador Conjunto 15-12-2015

# %%
for key in sorted(secciones.keys()):
    print(key)
    print()
    print('--------------------------------------------------------------------')
    readfile = open(secciones[key], 'r')
    text = readfile.read()
    sentences = text.split('.')
    regexp = re.compile(r'[ .,;\'\"]víctimas[ .,;\'\"]')
    data_paz = ''
    for s in sentences: 
        if regexp.search(s.lower()): 
            data_paz = data_paz + '\n' + s

    stop_words = stop_words_spanish[:]
    stop_words.append('víctimas')
    final1 = getNGram(data_paz, 1,stop_words , 20)
    final2 = getNGram(data_paz, 2,stop_words , 20)
    final3 = []
    for i in range(0,20):
        final3.append(final1[i] + final2[i])
    print(tabulate(final3, ['Unigrams', 'Number', 'Bigrams', 'Number'],  tablefmt="presto", numalign="center"))
    print('--------------------------------------------------------------------')
    print()
# Out:
# 5.1.1 Verdad
#
# --------------------------------------------------------------------
#  Unigrams       |  Number  | Bigrams                   |  Number
# ----------------+----------+---------------------------+----------
#  comisión       |    14    | derechos humanos          |    5
#  conflicto      |    13    | personas desaparecidas    |    4
#  derechos       |    13    | gobierno nacional         |    3
#  organizaciones |    11    | sistema integral          |    2
#  participación  |    8     | personas dadas            |    2
#  sociedad       |    7     | diferentes voces          |    2
#  nacional       |    6     | sociedad incluyendo       |    2
#  desaparecidas  |    6     | primer lugar              |    2
#  reparación     |    6     | estarán centrados         |    1
#  contribuir     |    6     | entidad depositaria       |    1
#  repetición     |    6     | otras unidad              |    1
#  ubpd           |    6     | creará espacios           |    1
# ...

# %% [markdown]
# ## Frecuencias de 'víctimas' por sección (ya que no aparece en los más populares)

# %%
for key in sorted(secciones.keys()):
    print(key)
    print()
    print('--------------------------------------------------------------------')
    readfile = open(secciones[key], 'r')
    text = readfile.read()
    final45 = getNGram(text, 1, stop_words_spanish, -1)
    final46 = []
    for i in final45:
        if 'víctima' in i[0]:
            final46.append(i)
    print(tabulate(final46, ['Ngrams', 'Number'],  tablefmt="presto", numalign="center"))
    print('---------------------------------------------------------------------')
    print()
# Out:
# 5.1.1 Verdad
#
# --------------------------------------------------------------------
#  Ngrams   |  Number
# ----------+----------
#  víctimas |    33
# ---------------------------------------------------------------------
#
# 5.1.2 Justicia
#
# --------------------------------------------------------------------
#  Ngrams   |  Number
# ----------+----------
#  víctimas |    30
#  víctima  |    1
# ---------------------------------------------------------------------
#
# 5.1.3 Reparación
#
# --------------------------------------------------------------------
#  Ngrams   |  Number
# ----------+----------
#  víctimas |    52
#  víctima  |    1
# ---------------------------------------------------------------------
#
# 5.1.4 No repetición
#
# --------------------------------------------------------------------
#  Ngrams   |  Number
# ----------+----------
#  víctimas |    3
# ---------------------------------------------------------------------
